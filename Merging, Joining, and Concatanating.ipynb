# %%
import pandas as pd

# %%
df1 = pd.read_csv('bigmac.csv')

# %%
df2 = pd.read_csv('jamesbond.csv')

# %%
df3 = pd.read_csv('bouts_out_new.csv')

# %%
df1.head()
# Out:
#      Date    Country  Price in US Dollars
# 0  1/2016  Argentina                 2.39
# 1  1/2016  Australia                 3.74
# 2  1/2016     Brazil                 3.35
# 3  1/2016    Britain                 4.22
# 4  1/2016     Canada                 4.14

# %%
df2.head()
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
# 4          Casino Royale  1967   David Niven     Ken Hughes       315.0
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7
# 4    85.0                NaN

# %%
df3.head()
# Out:
#    age_A  age_B  height_A  height_B  reach_A  reach_B  stance_A  stance_B  \
# 0   35.0   27.0     179.0     175.0    178.0    179.0  orthodox  orthodox
# 1   26.0   31.0     175.0     185.0    179.0    185.0  orthodox  orthodox
# 2   28.0   26.0     176.0     175.0      NaN    179.0  orthodox  orthodox
# 3   25.0   29.0     175.0     174.0    179.0    180.0  orthodox  orthodox
# 4   25.0   35.0     175.0     170.0    179.0    170.0  orthodox  orthodox
#
#    weight_A  weight_B   ...     kos_A  kos_B  result  decision  judge1_A  \
# 0     160.0     160.0   ...        33   34.0    draw        SD     110.0
# 1     164.0     164.0   ...        34   32.0   win_A        UD     120.0
# 2     154.0     154.0   ...        13   33.0   win_B        KO       NaN
# 3     155.0     155.0   ...        32   19.0   win_A        KO      47.0
# 4     155.0       NaN   ...        32   33.0   win_A        UD     118.0
#
#    judge1_B  judge2_A  judge2_B judge3_A judge3_B
# ...

# %%
pd.concat([df1, df2, df3], axis=1)# by defaut it concatnate along rows
# Out:
#           Date         Country  Price in US Dollars  \
# 0       1/2016       Argentina                 2.39
# 1       1/2016       Australia                 3.74
# 2       1/2016          Brazil                 3.35
# 3       1/2016         Britain                 4.22
# 4       1/2016          Canada                 4.14
# 5       1/2016           Chile                 2.94
# 6       1/2016           China                 2.68
# 7       1/2016        Colombia                 2.43
# 8       1/2016      Costa Rica                 4.02
# 9       1/2016  Czech Republic                 2.98
# 10      1/2016         Denmark                 4.32
# 11      1/2016           Egypt                 2.16
# 12      1/2016       Euro area                 4.00
# 13      1/2016       Hong Kong                 2.48
# 14      1/2016         Hungary                 3.08
# 15      1/2016           India                 1.90
# 16      1/2016       Indonesia                 2.19
# ...

# %%
left = pd.DataFrame({'key': ['K0', 'K1', 'K2'],
                    'A': ['A0', 'A1', 'A2'],
                    'B': ['B0', 'B1', 'B2']})
right = pd.DataFrame({'key': ['K0', 'K1', 'K2'],
                    'C': ['C0', 'C1', 'C2'],
                    'D': ['D0', 'D1', 'D2']})

# %%
left
# Out:
#   key   A   B
# 0  K0  A0  B0
# 1  K1  A1  B1
# 2  K2  A2  B2

# %%
right
# Out:
#   key   C   D
# 0  K0  C0  D0
# 1  K1  C1  D1
# 2  K2  C2  D2

# %%
pd.merge(left, right, how='inner', on='key')
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K1  A1  B1  C1  D1
# 2  K2  A2  B2  C2  D2

# %%
pd.merge(left, right, how='outer', on='key')
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K1  A1  B1  C1  D1
# 2  K2  A2  B2  C2  D2

# %%
left = pd.DataFrame({'key1': ['K0', 'K1', 'K2'],
                     'key2': ['K0', 'K1', 'K2'],
                    'A': ['A0', 'A1', 'A2'],
                    'B': ['B0', 'B1', 'B2']})
right = pd.DataFrame({'key1': ['K0', 'K1', 'K2'],
                    'key2': ['K0', 'K1', 'K2'],
                    'C': ['C0', 'C1', 'C2'],
                    'D': ['D0', 'D1', 'D2']})

# %%
pd.merge(left, right, on=['key1', 'key2'])
# Out:
#   key1 key2   A   B   C   D
# 0   K0   K0  A0  B0  C0  D0
# 1   K1   K1  A1  B1  C1  D1
# 2   K2   K2  A2  B2  C2  D2

# %% [markdown]
# # Joining

# %%
left = pd.DataFrame({'A': ['A0', 'A1', 'A2'],
                    'B': ['B0', 'B1', 'B2']}, 
                   index=['K0', 'K1', 'K2'])
right = pd.DataFrame({'C': ['C0', 'C1', 'C2'],
                    'D': ['D0', 'D1', 'D2']},
                    index=['K0', 'K1', 'K2'])

# %%
left.join(right)
# Out:
#      A   B   C   D
# K0  A0  B0  C0  D0
# K1  A1  B1  C1  D1
# K2  A2  B2  C2  D2

# %%
left.join(right, how='outer')
# Out:
#      A   B   C   D
# K0  A0  B0  C0  D0
# K1  A1  B1  C1  D1
# K2  A2  B2  C2  D2

# %%
left.join(right, how='right')
# Out:
#      A   B   C   D
# K0  A0  B0  C0  D0
# K1  A1  B1  C1  D1
# K2  A2  B2  C2  D2
