# %% [markdown]
# # PANDAS- OPERATION

# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('bigmac.csv')

# %%
df.head(3)
# Out:
#      Date    Country  Price in US Dollars
# 0  1/2016  Argentina                 2.39
# 1  1/2016  Australia                 3.74
# 2  1/2016     Brazil                 3.35

# %%
len(df['Date'].unique())
# Out:
# 12

# %%
df['Date'].nunique()
# Out:
# 12

# %%
df['Price in US Dollars'].value_counts()
# Out:
# 4.00    10
# 3.27     8
# 3.54     7
# 2.43     7
# 2.67     7
# 4.94     6
# 2.19     5
# 4.16     5
# 2.93     5
# 2.92     5
# 3.76     5
# 4.63     5
# 3.34     5
# 4.05     5
# 2.55     5
# 2.33     5
# 5.02     5
# 3.20     4
# 3.59     4
# 4.25     4
# 4.91     4
# 3.00     4
# 2.74     4
# 4.41     4
# 3.23     4
# 2.46     4
# 2.98     4
# 1.83     4
# 4.68     4
# 2.86     4
#         ..
# 2.82     1
# 6.39     1
# 5.39     1
# 5.56     1
# 4.78     1
# 1.20     1
# 2.01     1
# 6.79     1
# 5.36     1
# 4.22     1
# 4.20     1
# 1.36     1
# 2.17     1
# 5.27     1
# 7.84     1
# 5.23     1
# 7.54     1
# 4.51     1
# 4.70     1
# 1.67     1
# 1.58     1
# 3.51     1
# 2.12     1
# 3.90     1
# 4.55     1
# 3.97     1
# 3.96     1
# 2.90     1
# 1.77     1
# 3.66     1
# Name: Price in US Dollars, Length: 330, dtype: int64

# %%
df[(df['Price in US Dollars']>4) &(df['Price in US Dollars']<20)]
# Out:
#        Date        Country  Price in US Dollars
# 3    1/2016        Britain                 4.22
# 4    1/2016         Canada                 4.14
# 8    1/2016     Costa Rica                 4.02
# 10   1/2016        Denmark                 4.32
# 17   1/2016         Israel                 4.29
# 22   1/2016         Norway                 5.21
# 33   1/2016         Sweden                 5.23
# 34   1/2016    Switzerland                 6.44
# 40   1/2016  United States                 4.93
# 45   1/2016        Belgium                 4.25
# 47   1/2016        Finland                 4.41
# 48   1/2016         France                 4.41
# 51   1/2016        Ireland                 4.25
# 52   1/2016          Italy                 4.30
# 58   7/2015         Brazil                 4.28
# 59   7/2015        Britain                 4.51
# 60   7/2015         Canada                 4.54
# 64   7/2015     Costa Rica                 4.03
# 66   7/2015        Denmark                 5.08
# ...

# %%
def times2(x):
    return x*2

# %%
df['Price in US Dollars'].apply(times2)
# Out:
# 0       4.78
# 1       7.48
# 2       6.70
# 3       8.44
# 4       8.28
# 5       5.88
# 6       5.36
# 7       4.86
# 8       8.04
# 9       5.96
# 10      8.64
# 11      4.32
# 12      8.00
# 13      4.96
# 14      6.16
# 15      3.80
# 16      4.38
# 17      8.58
# 18      6.24
# 19      3.64
# 20      5.62
# 21      7.82
# 22     10.42
# 23      5.72
# 24      5.86
# 25      5.58
# 26      4.74
# 27      3.06
# 28      6.40
# 29      6.54
#        ...
# 622     3.82
# 623     7.72
# 624     4.48
# 625     7.98
# 626     7.00
# 627     6.18
# 628     5.74
# 629     4.16
# 630     5.00
# 631     7.22
# 632    14.04
# 633     4.84
# 634     5.62
# 635     4.42
# 636     5.72
# 637     4.68
# 638     5.34
# 639     6.38
# 640     4.92
# 641     5.96
# 642     3.66
# 643    11.02
# 644    12.60
# 645     4.72
# 646     4.22
# 647     7.66
# 648     5.98
# 649     3.66
# 650     7.16
# 651     6.64
# Name: Price in US Dollars, Length: 652, dtype: float64

# %%
df['Price in US Dollars'].apply(lambda x:x*2)
# Out:
# 0       4.78
# 1       7.48
# 2       6.70
# 3       8.44
# 4       8.28
# 5       5.88
# 6       5.36
# 7       4.86
# 8       8.04
# 9       5.96
# 10      8.64
# 11      4.32
# 12      8.00
# 13      4.96
# 14      6.16
# 15      3.80
# 16      4.38
# 17      8.58
# 18      6.24
# 19      3.64
# 20      5.62
# 21      7.82
# 22     10.42
# 23      5.72
# 24      5.86
# 25      5.58
# 26      4.74
# 27      3.06
# 28      6.40
# 29      6.54
#        ...
# 622     3.82
# 623     7.72
# 624     4.48
# 625     7.98
# 626     7.00
# 627     6.18
# 628     5.74
# 629     4.16
# 630     5.00
# 631     7.22
# 632    14.04
# 633     4.84
# 634     5.62
# 635     4.42
# 636     5.72
# 637     4.68
# 638     5.34
# 639     6.38
# 640     4.92
# 641     5.96
# 642     3.66
# 643    11.02
# 644    12.60
# 645     4.72
# 646     4.22
# 647     7.66
# 648     5.98
# 649     3.66
# 650     7.16
# 651     6.64
# Name: Price in US Dollars, Length: 652, dtype: float64

# %%
df.columns
# Out:
# Index(['Date', 'Country', 'Price in US Dollars'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=652, step=1)

# %%
df.sort_values('Price in US Dollars')
# Out:
#        Date       Country  Price in US Dollars
# 42   1/2016     Venezuela                 0.66
# 98   7/2015     Venezuela                 0.67
# 151  1/2015       Ukraine                 1.20
# 139  1/2015        Russia                 1.36
# 297  7/2013         India                 1.50
# 27   1/2016        Russia                 1.53
# 240  1/2014         India                 1.54
# 39   1/2016       Ukraine                 1.54
# 95   7/2015       Ukraine                 1.55
# 411  7/2012         India                 1.58
# 467  1/2012         India                 1.62
# 208  7/2014       Ukraine                 1.63
# 354  1/2013         India                 1.67
# 183  7/2014         India                 1.75
# 30   1/2016  South Africa                 1.77
# 19   1/2016      Malaysia                 1.82
# 642  1/2010     Sri Lanka                 1.83
# 649  1/2010       Ukraine                 1.83
# 71   7/2015         India                 1.83
# ...

# %%
df.isnull()
# Out:
#       Date  Country  Price in US Dollars
# 0    False    False                False
# 1    False    False                False
# 2    False    False                False
# 3    False    False                False
# 4    False    False                False
# 5    False    False                False
# 6    False    False                False
# 7    False    False                False
# 8    False    False                False
# 9    False    False                False
# 10   False    False                False
# 11   False    False                False
# 12   False    False                False
# 13   False    False                False
# 14   False    False                False
# 15   False    False                False
# 16   False    False                False
# 17   False    False                False
# 18   False    False                False
# 19   False    False                False
# 20   False    False                False
# 21   False    False                False
# ...

# %%
df = pd.read_csv('chicago.csv')

# %%
df['Employee Annual Salary'] = df['Employee Annual Salary'].str.replace('$', '')

# %%
df
# Out:
#                            Name  \
# 0               AARON,  ELVIA J
# 1             AARON,  JEFFERY M
# 2                AARON,  KARINA
# 3           AARON,  KIMBERLEI R
# 4           ABAD JR,  VICENTE M
# 5               ABARCA,  ANABEL
# 6             ABARCA,  EMMANUEL
# 7             ABASCAL,  REECE E
# 8          ABBASI,  CHRISTOPHER
# 9         ABBATACOLA,  ROBERT J
# 10        ABBATEMARCO,  JAMES J
# 11             ABBATE,  TERRY M
# 12             ABBOTT,  BETTY L
# 13            ABBOTT,  LYNISE M
# 14       ABBRUZZESE,  WILLIAM J
# 15              ABDALLAH,  ZAID
# 16        ABDELHADI,  ABDALMAHD
# 17          ABDELLATIF,  AREF R
# 18           ABDELMAJEID,  AZIZ
# 19          ABDOLLAHZADEH,  ALI
# 20     ABDUL-KARIM,  MUHAMMAD A
# 21          ABDULLAH,  DANIEL N
# 22             ABDULLAH,  KEVIN
# 23         ABDULLAH,  LAKENYA N
# 24          ABDULLAH,  RASHAD J
# 25         ABDULSATTAR,  MUDHAR
# 26         ABDUL-SHAKUR,  TAHIR
# 27       ABDULWAHAB,  ABUUBAIDA
# ...

# %%
df.pivot_table(values='Name', index='Position Title', columns ='Employee Annual Salary', aggfunc='sum')
# Out:
# Employee Annual Salary                                      0.96 100048.00  \
# Position Title
# 1ST DEPUTY INSPECTOR GENERAL                                 NaN       NaN
# A/MGR COM SVC-ELECTIONS                                      NaN       NaN
# A/MGR OF MIS-ELECTIONS                                       NaN       NaN
# A/MGR WAREHOUSE-ELECTIONS                                    NaN       NaN
# A/SUPRV REDISTRICTING                                        NaN       NaN
# ACCIDENT ADJUSTER                                            NaN       NaN
# ACCOUNTANT I                                                 NaN       NaN
# ACCOUNTANT II                                                NaN       NaN
# ACCOUNTANT III                                               NaN       NaN
# ACCOUNTANT IV                                                NaN       NaN
# ACCOUNTING TECHNICIAN I                                      NaN       NaN
# ...
